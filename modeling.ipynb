# %% [markdown]
# Build a model based on the data you have scraped. Don't worry if the model is far from perfect. You can always improve later. The most important thing is your story, you can answer the following questions after you finish modeling.

# %% [markdown]
# 1. Why this project is important? What problem are you trying to solve?

# %% [markdown]
# With customer churn prediction, the company will be able to identify which customers are likely to switch providers. By accurately predicting churn, the companies can strategically allocate resources to retain at-risk customers rather than spending extensively on customer acquisition. This approach preserves revenue, improves customer loyalty, and optimizes operational costs, providing a more efficient and effective way to manage customer relationships in a highly competitive industry.

# %% [markdown]
# 2. How do you measure the model performance (metrics)? What is the benchmark?

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 3. How is your model? Have achieved your goal? How to evaluate the business value of your model?

# %% [markdown]
# Business Value is calculated based on:
# Monthly average payment of customer is 64 dollars.
# Cost of marketing promotion is 20 dollars per customer per month (Assumption:with input from marketing dep in real case)
# From all correctly identified churn customers, 30% will not churn after marketing actions
#
# The model is not done yet. Will update once have the data.

# %% [markdown]
# 4. Any insights have you gotten from your model? Any actionable suggestions can you provide to your business partner?

# %% [markdown]
# For customers with lower probability to churn, push special service/promotion package options;  for customer with high probability to churn, only try to keep high value customers considering the cost to keep those customers can be high
#
# Low tenure customer tends to churn, and monthly charge between $70-$100 has higher churn rate. Special promotion to lower customer monthly payment in first 3 months to enhance customer loyalty
#
# Predicted churned customer with monthly payment more than $30(with $20 marketing cost to keep the customer) are worthy to be included in the promotion plan
#
# Zip code 92000 has much higher churn rate (33%)  than all other regions. Suggest to check if any service weakness/issues in this area (by reward-based survey with the targeted customer group)
#
# Age Group 65+   has really high churn rate 85% when taking a month-to-month contract

# %% [markdown]
# 5. What is the most challenging part in the project? How did you solve it? How will you futher improve your model if you get more resources and time.

# %% [markdown]
# EDA.
# 1. With some features, dont know how to decide if it is relevant or not, except by testing with the model metrics.
# 2. Meaning of some data columns are not clear, cannot find out how those data was collected and if they have business meaning. In real business case, those probably can be clarified
#
# It will be more precise to forecast user behavior change if can collect history usage data.
# Also more customer profile data can be good features for the model

# %% [markdown]
# Make sure that your work includes these parts:
# 1. **Pre-model Analysis**: process and visualize data; get insights of features and target.
# 2. **Problem Definition**: translate the business needs into machine learning problems; design metrics to measure model performance.
# 3. **Feature Engineering**: create features which might improve model performance.
# 4. **Modeling**: Model selection, feature elimination, validation, hyperparameter tuning.
# 5. **Post-model Analysis**: Model performance, feature importance, actionable suggestions to business.
